# %%
from utils import *

# %% [markdown]
# # Data statistics and visualizations

# %% [markdown]
# **Load data.**

# %%
results = pd.read_csv("../data/results.csv", index_col=0)

# %%
results.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 720 entries, 0 to 725
# Data columns (total 34 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   respondent              720 non-null    int64
#  1   task                    720 non-null    int64
#  2   complexity              720 non-null    float64
#  3   interval                720 non-null    object
#  4   time                    720 non-null    float64
#  5   company                 720 non-null    float64
#  6   purpose                 720 non-null    float64
#  7   purpose_tokens          697 non-null    object
#  8   purpose_token_count     720 non-null    int64
#  9   purpose_word_count      720 non-null    int64
#  10  detail                  720 non-null    float64
#  11  desc_tokens             714 non-null    object
#  12  desc_token_count        720 non-null    int64
#  13  desc_token_count_group  720 non-null    object
#  14  desc_word_count         720 non-null    int64
#  15  desc_word_count_group   720 non-null    object
#  16  desc_eval_comp          720 non-null    int64
#  17  desc_eval_elem          720 non-null    int64
#  18  desc_eval_char          720 non-null    int64
#  19  desc_eval_sum           720 non-null    int64
#  20  PQ1                     720 non-null    int64
#  21  ATT1                    720 non-null    int64
#  22  PQ2                     720 non-null    int64
#  23  HQ1                     720 non-null    int64
#  24  PQ3                     720 non-null    int64
#  25  HQ2                     720 non-null    int64
#  26  HQ3                     720 non-null    int64
#  27  ATT2                    720 non-null    int64
#  28  PQ4                     720 non-null    int64
#  29  HQ4                     720 non-null    int64
#  30  PQ                      720 non-null    float64
#  31  HQ                      720 non-null    float64
#  32  ATT                     720 non-null    float64
#  33  familiarity             720 non-null    bool
# dtypes: bool(1), float64(8), int64(20), object(5)
# memory usage: 192.0+ KB

# %%
results.head()
# Out:
#    respondent  task  complexity interval   time  company  purpose  \
# 0           3     1        0.22       2s   94.0      1.0      1.0
# 1           3     2        2.00       2s  425.0      0.0      1.0
# 2           3     3        2.97       2s   73.0      1.0      1.0
# 3           3     4        5.27       2s   85.0      1.0      1.0
# 4           3     5        7.50       2s  413.0      1.0      1.0
#
#                 purpose_tokens  purpose_token_count  purpose_word_count  ...  \
# 0                     clothing                    1                   1  ...
# 1  glass contact lens sunglass                    4                   4  ...
# 2                   sport gear                    2                   2  ...
# 3          information weather                    2                   4  ...
# 4                       supply                    1                   2  ...
#
#    PQ3 HQ2  HQ3 ATT2  PQ4 HQ4    PQ    HQ  ATT  familiarity
# 0    6   5    6    7    7   7  6.75  6.00  7.0        False
# 1    6   6    6    7    7   7  6.50  6.25  6.5        False
# 2    5   6    6    7    7   6  6.25  6.00  7.0        False
# 3    7   5    6    7    7   6  7.00  5.75  7.0        False
# 4    5   4    5    6    6   4  5.50  4.25  5.5        False
#
# [5 rows x 34 columns]

# %% [markdown]
# **Basic stats.**

# %%
results[[x for x in attrak]].describe()
# Out:
#               PQ1         PQ2         PQ3         PQ4         HQ1         HQ2  \
# count  720.000000  720.000000  720.000000  720.000000  720.000000  720.000000
# mean     4.611111    4.981944    4.797222    4.777778    4.315278    4.090278
# std      1.592363    1.373687    1.296403    1.566533    1.294813    1.325440
# min      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
# 25%      3.000000    4.000000    4.000000    4.000000    4.000000    3.000000
# 50%      5.000000    5.000000    5.000000    5.000000    4.000000    4.000000
# 75%      6.000000    6.000000    6.000000    6.000000    5.000000    5.000000
# max      7.000000    7.000000    7.000000    7.000000    7.000000    7.000000
#
#               HQ3         HQ4        ATT1        ATT2          PQ          HQ  \
# count  720.000000  720.000000  720.000000  720.000000  720.000000  720.000000
# mean     3.877778    4.045833    4.388889    4.583333    4.792014    4.082292
# std      1.348385    1.348510    1.482917    1.335823    1.249223    1.174048
# min      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
# 25%      3.000000    3.000000    3.000000    4.000000    4.000000    3.250000
# 50%      4.000000    4.000000    5.000000    5.000000    5.000000    4.000000
# 75%      5.000000    5.000000    5.000000    5.000000    5.750000    5.000000
# max      7.000000    7.000000    7.000000    7.000000    7.000000    7.000000
#
#               ATT
# count  720.000000
# mean     4.486111
# std      1.323197
# min      1.000000
# 25%      3.500000
# 50%      4.500000
# 75%      5.500000
# max      7.000000

# %%
results[[x for x in open_text]].describe()
# Out:
#           company     purpose  purpose_token_count  purpose_word_count  \
# count  720.000000  720.000000           720.000000          720.000000
# mean     0.928472    0.845139             2.637500            4.191667
# std      0.241882    0.336643             1.867066            4.387926
# min      0.000000    0.000000             0.000000            0.000000
# 25%      1.000000    1.000000             2.000000            2.000000
# 50%      1.000000    1.000000             2.000000            3.000000
# 75%      1.000000    1.000000             3.000000            5.000000
# max      1.000000    1.000000            20.000000           61.000000
#
#            detail  desc_eval_comp  desc_eval_elem  desc_eval_char  \
# count  720.000000      720.000000      720.000000      720.000000
# mean     0.277083        0.925000        1.538889        0.448611
# std      0.441221        0.871389        1.190430        0.660950
# min      0.000000        0.000000        0.000000        0.000000
# 25%      0.000000        0.000000        1.000000        0.000000
# 50%      0.000000        1.000000        1.000000        0.000000
# 75%      1.000000        1.000000        2.000000        1.000000
# max      1.000000        3.000000        5.000000        3.000000
#
#        desc_eval_sum  desc_token_count  desc_word_count
# count      720.00000        720.000000       720.000000
# mean         1.98750          9.879167        21.244444
# std          1.30522          6.541883        16.198910
# min          0.00000          0.000000         0.000000
# 25%          1.00000          5.000000        10.000000
# 50%          2.00000          8.000000        17.000000
# 75%          3.00000         13.000000        28.000000
# max          6.00000         40.000000       110.000000

# %% [markdown]
# **Histograms**

# %%
for column in attrak:
    my_hist_with_qq(results, column, column, attrak[column])
# Out:
# C:\Users\mkrajcovic\Desktop\research-fivesecondtest\analysis\.venv\lib\site-packages\outdated\utils.py:14: OutdatedPackageWarning: The package pingouin is out of date. Your version is 0.5.2, the latest is 0.5.3.
# Set the environment variable OUTDATED_IGNORE=1 to disable these warnings.
#   return warn(

# %% [markdown]
# Normality tests

# %%
for column in ['PQ', 'HQ', 'ATT']:
    print(column)
    print(stats.shapiro(results[column]), end='\n\n')
# Out:
# PQ
# ShapiroResult(statistic=0.971467137336731, pvalue=1.2272392824197453e-10)
#
# HQ
# ShapiroResult(statistic=0.9921110272407532, pvalue=0.0007123833056539297)
#
# ATT
# ShapiroResult(statistic=0.9757741689682007, pvalue=1.5136679687444143e-09)

# %%
for column in open_text:
    my_hist_with_qq(results, column, column, open_text[column])

# %%
for column in open_text:
    print(column)
    print(stats.shapiro(results[column]), end='\n\n')
# Out:
# company
# ShapiroResult(statistic=0.31445014476776123, pvalue=1.401298464324817e-45)
#
# purpose
# ShapiroResult(statistic=0.4899052381515503, pvalue=4.3325345919994694e-41)
#
# purpose_token_count
# ShapiroResult(statistic=0.7854874134063721, pvalue=1.0649344615737769e-29)
#
# purpose_word_count
# ShapiroResult(statistic=0.5969728827476501, pvalue=8.433194645548954e-38)
#
# detail
# ShapiroResult(statistic=0.5761572122573853, pvalue=1.7176001142116005e-38)
#
# desc_eval_comp
# ShapiroResult(statistic=0.826348066329956, pvalue=3.2590182073632484e-27)
#
# desc_eval_elem
# ShapiroResult(statistic=0.9003420472145081, pvalue=3.1519133610481e-21)
#
# desc_eval_char
# ShapiroResult(statistic=0.6765130758285522, pvalue=7.352450267482699e-35)
#
# desc_eval_sum
# ShapiroResult(statistic=0.9297374486923218, pvalue=7.249251242556512e-18)
#
# desc_token_count
# ShapiroResult(statistic=0.909411609172821, pvalue=2.801583186534678e-20)
#
# desc_word_count
# ShapiroResult(statistic=0.8679252862930298, pvalue=3.647286167945317e-24)

# %% [markdown]
# **Boxplots Attrak-Diff.**

# %%
my_box(results, [x for x in results.columns if x in attrak], 'Attrak-diff ratings', 'Quality', None, (5, 10))

# %% [markdown]
# **Categorical data**

# %%
my_pie(results, 'company', 'Webpage\'s company question (1=correct, 0=incorrect)')

# %%
my_pie(results, 'purpose', 'Webpage\'s purpose question (1=correct, 0=incorrect)')

# %%
my_pie(results, 'detail', 'Webpage\'s detail question (1=correct, 0=incorrect)')

# %%
my_bar(results, 'desc_eval_elem', 'Description question - identifed elements')

# %%
my_bar(results, 'desc_eval_char', 'Description question - identifed characteristics')

# %%
my_bar(results, 'desc_eval_comp', 'Description question - complexity')

# %%
my_bar(results, 'desc_eval_sum', 'Description question - identifed characteristics and elements')

# %% [markdown]
# **Word counts.**

# %%
my_box(results, ['desc_token_count', 'desc_word_count'], 'Description question word counts')

# %%
my_box(results, ['purpose_token_count', 'purpose_word_count'], 'Purpose question word counts')

# %% [markdown]
# **Time per task**

# %%
results.time.mean()
# Out:
# 135.41023611111112

# %%
results.groupby(['task']).time.mean()
# Out:
# task
# 1    128.441667
# 2    130.616667
# 3    148.341667
# 4    122.725000
# 5    137.811417
# 6    144.525000
# Name: time, dtype: float64

# %% [markdown]
# **Straightlining detection.**

# %%
print('Detected straightlining:\n')
for index, row in results.iterrows():
    if(np.std(row[attrak.keys()]) < 0.3):
        print('Respondent ' + str(row.respondent) + ', task ' + str(row.task) + ', ' + row.interval + ' condition.  STD = ' + str(np.std(row[attrak.keys()])))
# Out:
# Detected straightlining:
#
# Respondent 10, task 6, 2s condition.  STD = 0.2692307692307693
# Respondent 13, task 1, 2s condition.  STD = 0.0
# Respondent 13, task 2, 2s condition.  STD = 0.28781979898261084
# Respondent 13, task 4, 2s condition.  STD = 0.0
# Respondent 13, task 5, 2s condition.  STD = 0.0
# Respondent 13, task 6, 2s condition.  STD = 0.0
# Respondent 22, task 2, 2s condition.  STD = 0.2692307692307693
# Respondent 26, task 1, 2s condition.  STD = 0.0
# Respondent 26, task 2, 2s condition.  STD = 0.0
# Respondent 26, task 3, 2s condition.  STD = 0.0
# Respondent 26, task 4, 2s condition.  STD = 0.0
# Respondent 26, task 5, 2s condition.  STD = 0.0
# Respondent 26, task 6, 2s condition.  STD = 0.0
# Respondent 34, task 3, 2s condition.  STD = 0.0
# Respondent 38, task 5, 2s condition.  STD = 0.0
# Respondent 38, task 6, 2s condition.  STD = 0.0
# Respondent 47, task 5, 2s condition.  STD = 0.0
# Respondent 9, task 2, 5s condition.  STD = 0.2692307692307693
# Respondent 9, task 3, 5s condition.  STD = 0.2692307692307693
# Respondent 10, task 6, 5s condition.  STD = 0.2878197989826109
# Respondent 15, task 2, 5s condition.  STD = 0.0
# Respondent 15, task 3, 5s condition.  STD = 0.0
# Respondent 15, task 4, 5s condition.  STD = 0.28781979898261084
# Respondent 15, task 5, 5s condition.  STD = 0.0
# Respondent 17, task 3, 5s condition.  STD = 0.2692307692307693
# Respondent 19, task 2, 5s condition.  STD = 0.0
# Respondent 25, task 1, 5s condition.  STD = 0.28781979898261084
# Respondent 42, task 2, 5s condition.  STD = 0.0
# Respondent 44, task 4, 5s condition.  STD = 0.0
# Respondent 48, task 1, 5s condition.  STD = 0.2692307692307693
# Respondent 2, task 3, 10s condition.  STD = 0.0
# Respondent 16, task 5, 10s condition.  STD = 0.0
# Respondent 21, task 3, 10s condition.  STD = 0.2692307692307693
# Respondent 25, task 3, 10s condition.  STD = 0.2692307692307693
# Respondent 32, task 1, 10s condition.  STD = 0.0
# Respondent 32, task 3, 10s condition.  STD = 0.0
# Respondent 34, task 5, 10s condition.  STD = 0.0
# Respondent 40, task 6, 10s condition.  STD = 0.2692307692307693
# Respondent 42, task 5, 10s condition.  STD = 0.0
# Respondent 42, task 6, 10s condition.  STD = 0.0

# %% [markdown]
# ## Word clouds

# %%
tasks = {1:'',2:'',3:'',4:'',5:'',6:''}

for index, row in results.iterrows():
    tasks[row.task] += (row.desc_tokens + ' ') if type(row.desc_tokens) == str else ''

for task in tasks: 
    print('task ' + str(task) + ' (description)')
    plt.imshow(WordCloud(collocations = False, background_color = 'white').generate(tasks[task]), interpolation='bilinear')
    plt.axis("off")
    plt.show()
    
for index, row in results.iterrows():
    tasks[row.task] = ''
    tasks[row.task] += (row.purpose_tokens + ' ') if type(row.purpose_tokens) == str else ''

for task in tasks: 
    print('task ' + str(task) + ' (purpose)')
    plt.imshow(WordCloud(collocations = False, background_color = 'white').generate(tasks[task]), interpolation='bilinear')
    plt.axis("off")
    plt.show()
# Out:
# task 1 (description)
# task 2 (description)
# task 3 (description)
# task 4 (description)
# task 5 (description)
# task 6 (description)
# task 1 (purpose)
# task 2 (purpose)
# task 3 (purpose)
# task 4 (purpose)
# task 5 (purpose)
# task 6 (purpose)

# %% [markdown]
# ## Questionnaire reliability

# %%
cronbach_alpha(results[['PQ1', 'PQ2', 'PQ3', 'PQ4']])
# Out:
# (0.8763749796049317, array([0.861, 0.89 ]))

# %%
cronbach_alpha(results[['HQ1', 'HQ2', 'HQ3', 'HQ4']])
# Out:
# (0.9059048714153446, array([0.894, 0.917]))

# %%
cronbach_alpha(results[['ATT1', 'ATT2']])
# Out:
# (0.8624197356517129, array([0.841, 0.881]))

# %% [markdown]
# ## Question order effect

# %%
results_2s = pd.read_csv("../data/raw_data/5ST case study - 2 seconds - Raw results.csv")
results_5s = pd.read_csv("../data/raw_data/5ST case study - 5 seconds - Raw results.csv")
results_10s = pd.read_csv("../data/raw_data/5ST case study - 10 seconds - Raw results.csv")

# %%
results_2s['interval'] = '2s'
results_5s['interval'] = '5s'
results_10s['interval'] = '10s'
results_2s = results_2s[(results_2s['respondent number'] != 40) | (results_2s.interval != '2s')]

# %%
orders = pd.concat([
    results_2s[['respondent number', 'task number', 'interval']],
    results_5s[['respondent number', 'task number', 'interval']],
    results_10s[['respondent number', 'task number', 'interval']]
], ignore_index=True)

# %%
results_2s[results_2s.index % 7 == 0]['T1Q1: What is the company’s name?']
# Out:
# 0          Shoes Design
# 7          I don't know
# 14            fair shop
# 21        Cant remember
# 28           Don't know
# 35            fairstart
# 42          dont rember
# 49                  NaN
# 56            Fair Shop
# 63                  ABC
# 70           don't know
# 77              no idea
# 84              No idea
# 91         Did not see.
# 98             Fairshop
# 105           dont know
# 112           firstshop
# 119             no idea
# 126           lets walk
# 133             no idea
# 140         i dont know
# 147               Shoes
# 154              Shoes?
# 161          Fair Group
# 168                 NaN
# 175             No idea
# 182              Unsure
# 189            Shoes co
# 196           Fair Shop
# 203             no idea
# 210    Shoes collection
# 217                   ?
# 224           christmas
# 238       cant remember
# 245             no idea
# 252            not sure
# 259       I don't know.
# 266           Fair Shop
# 273     not sure. TESCO
# 280           Fair Shop
# Name: T1Q1: What is the company’s name?, dtype: object

# %%
results_5s[results_5s.index % 7 == 0]['T1Q1: What is the company’s name?']
# Out:
# 0                                     fire shop
# 7                                   dont recall
# 14                                     unknown
# 21                                    fair shop
# 28                                     Not sure
# 35                                    fair shop
# 42                                    Fair shop
# 49                                   Don't know
# 56            fair shop - but I can't remember
# 63                                   Don't know
# 70                                      company
# 77                                   Don't know
# 84                                 fair company
# 91                                    Fair Shop
# 98                                    Fair Shop
# 105                                   Dont know
# 112                                        Fair
# 119                                  don't know
# 126                              Didn't get it!
# 133                                    not sure
# 140                               Didn't notice
# 147                           I do not remember
# 154                                   Fair Shop
# 161                                    Wishlist
# 168                         Some retail company
# 175                                  Don't know
# 182                     Didn't look at the name
# 189                                   Dont know
# 196                                    Fairshop
# 203                                  don't know
# 210                                      Chores
# 217    I didn't see as focused on other details
# 224                                   Fair Shop
# 231                                       Shoes
# 238                                   fair shop
# 245                                   dont know
# 252                                     no idea
# 259                                         NaN
# 266                                         NaN
# 273                                     No idea
# Name: T1Q1: What is the company’s name?, dtype: object

# %%
results_10s[results_10s.index % 7 == 0]['T1Q1: What is the company’s name?']
# Out:
# 0                    Fair shop
# 7                     goodfood
# 14                I don't know
# 21           Your shoe company
# 28                   Fair shop
# 35                   Fair Shop
# 42                  Fair Point
# 49            i dont remember
# 56                        Free
# 63                   Fair shop
# 70                   Fair Shop
# 77         I didnt notice that
# 84                   Fair shop
# 91                   Dont know
# 98                   Fairright
# 105                 Don’t know
# 112               Sole support
# 119                  Fair Shop
# 126                  Fair shop
# 133             I don't recall
# 140                  Fair shop
# 147              Dont remember
# 154                   Fairshop
# 161                       Pass
# 168              cant remember
# 175                 First Sole
# 182                  Fair Shop
# 189                     Unsure
# 196                      shoes
# 203                  fair shop
# 210             Can't remember
# 217                   Fairshop
# 224                 Don't know
# 231                 Don't Know
# 238                  Dont Know
# 245                   Fairshop
# 252                      Twixt
# 259                  Fair Shop
# 266                        NaN
# 273    it began with F - FIRR?
# Name: T1Q1: What is the company’s name?, dtype: object

# %%
x = pd.DataFrame(columns=[1, 2, 3, 4, 5, 6])
for index, row in results.groupby(['interval','respondent']).mean(numeric_only=True).iterrows():
    resp_order = list(map(lambda x: x -1, orders[(orders['respondent number'] == index[1]) & (orders['interval'] == index[0]) & (orders['task number'] != 1)]['task number'].values))
    x.loc[len(x.index)] = [
        results[(results.interval == index[0]) & (results.respondent == index[1]) & (results.task == resp_order[0])]['company'].values[0],
        results[(results.interval == index[0]) & (results.respondent == index[1]) & (results.task == resp_order[1])]['company'].values[0],
        results[(results.interval == index[0]) & (results.respondent == index[1]) & (results.task == resp_order[2])]['company'].values[0],
        results[(results.interval == index[0]) & (results.respondent == index[1]) & (results.task == resp_order[3])]['company'].values[0],
        results[(results.interval == index[0]) & (results.respondent == index[1]) & (results.task == resp_order[4])]['company'].values[0],
        results[(results.interval == index[0]) & (results.respondent == index[1]) & (results.task == resp_order[5])]['company'].values[0],
    ]
for i in [1, 2, 3, 4, 5, 6]:
    print('company, task ' + str(i))
    print(x[i].value_counts())
# Out:
# company, task 1
# 1.0    111
# 0.5      5
# 0.0      4
# Name: 1, dtype: int64
# company, task 2
# 1.0    107
# 0.0     11
# 0.5      2
# Name: 2, dtype: int64
# company, task 3
# 1.0    110
# 0.0      5
# 0.5      5
# Name: 3, dtype: int64
# company, task 4
# 1.0    110
# 0.5      5
# 0.0      5
# Name: 4, dtype: int64
# company, task 5
# 1.0    109
# 0.0      8
# 0.5      3
# Name: 5, dtype: int64
# company, task 6
# 1.0    110
# 0.0      7
# 0.5      3
# Name: 6, dtype: int64

# %%
x = pd.DataFrame(columns=[1, 2, 3, 4, 5, 6])
for index, row in results.groupby(['interval','respondent']).mean(numeric_only=True).iterrows():
    resp_order = list(map(lambda x: x -1, orders[(orders['respondent number'] == index[1]) & (orders['interval'] == index[0]) & (orders['task number'] != 1)]['task number'].values))
    x.loc[len(x.index)] = [
        results[(results.interval == index[0]) & (results.respondent == index[1]) & (results.task == resp_order[0])]['purpose'].values[0],
        results[(results.interval == index[0]) & (results.respondent == index[1]) & (results.task == resp_order[1])]['purpose'].values[0],
        results[(results.interval == index[0]) & (results.respondent == index[1]) & (results.task == resp_order[2])]['purpose'].values[0],
        results[(results.interval == index[0]) & (results.respondent == index[1]) & (results.task == resp_order[3])]['purpose'].values[0],
        results[(results.interval == index[0]) & (results.respondent == index[1]) & (results.task == resp_order[4])]['purpose'].values[0],
        results[(results.interval == index[0]) & (results.respondent == index[1]) & (results.task == resp_order[5])]['purpose'].values[0],
    ]
for i in [1, 2, 3, 4, 5, 6]:
    print('purpose, task ' + str(i))
    print(x[i].value_counts())
# Out:
# purpose, task 1
# 1.0    96
# 0.0    17
# 0.5     7
# Name: 1, dtype: int64
# purpose, task 2
# 1.0    96
# 0.0    17
# 0.5     7
# Name: 2, dtype: int64
# purpose, task 3
# 1.0    99
# 0.5    11
# 0.0    10
# Name: 3, dtype: int64
# purpose, task 4
# 1.0    97
# 0.0    13
# 0.5    10
# Name: 4, dtype: int64
# purpose, task 5
# 1.0    100
# 0.0     14
# 0.5      6
# Name: 5, dtype: int64
# purpose, task 6
# 1.0    95
# 0.0    15
# 0.5    10
# Name: 6, dtype: int64

# %%
x = pd.DataFrame(columns=[1, 2, 3, 4, 5, 6])
for index, row in results.groupby(['interval','respondent']).mean(numeric_only=True).iterrows():
    resp_order = list(map(lambda x: x -1, orders[(orders['respondent number'] == index[1]) & (orders['interval'] == index[0]) & (orders['task number'] != 1)]['task number'].values))
    x.loc[len(x.index)] = [
        results[(results.interval == index[0]) & (results.respondent == index[1]) & (results.task == resp_order[0])]['detail'].values[0],
        results[(results.interval == index[0]) & (results.respondent == index[1]) & (results.task == resp_order[1])]['detail'].values[0],
        results[(results.interval == index[0]) & (results.respondent == index[1]) & (results.task == resp_order[2])]['detail'].values[0],
        results[(results.interval == index[0]) & (results.respondent == index[1]) & (results.task == resp_order[3])]['detail'].values[0],
        results[(results.interval == index[0]) & (results.respondent == index[1]) & (results.task == resp_order[4])]['detail'].values[0],
        results[(results.interval == index[0]) & (results.respondent == index[1]) & (results.task == resp_order[5])]['detail'].values[0],
    ]
for i in [1, 2, 3, 4, 5, 6]:
    print('detail, task ' + str(i))
    print(x[i].value_counts())
# Out:
# detail, task 1
# 0.0    83
# 1.0    31
# 0.5     6
# Name: 1, dtype: int64
# detail, task 2
# 0.0    90
# 1.0    30
# Name: 2, dtype: int64
# detail, task 3
# 0.0    84
# 1.0    34
# 0.5     2
# Name: 3, dtype: int64
# detail, task 4
# 0.0    82
# 1.0    36
# 0.5     2
# Name: 4, dtype: int64
# detail, task 5
# 0.0    84
# 1.0    31
# 0.5     5
# Name: 5, dtype: int64
# detail, task 6
# 0.0    89
# 1.0    29
# 0.5     2
# Name: 6, dtype: int64

# %% [markdown]
# ### Familiarity

# %%
results[results.familiarity == True]
# Out:
#      respondent  task  complexity interval   time  company  purpose  \
# 30            9     1        0.22       2s   98.0      1.0      1.0
# 33            9     4        5.27       2s   97.0      1.0      1.0
# 210          42     1        0.22       2s   93.0      1.0      1.0
# 242          50     3        2.97       2s  140.0      1.0      1.0
# 420          37     1        0.22       5s  235.0      1.0      1.0
# 435          40     4        5.27       5s  204.0      1.0      1.0
# 489           2     4        5.27      10s  244.0      1.0      1.0
# 516           9     1        0.22      10s  174.0      1.0      1.0
# 589          22     2        2.00      10s   59.0      1.0      1.0
# 630          30     1        0.22      10s   72.0      1.0      1.0
# 696          42     1        0.22      10s   90.0      1.0      1.0
#
#                                         purpose_tokens  purpose_token_count  \
# 30                                            clothing                    1
# 33                                    weather forecast                    2
# 210                               sustainable clothing                    2
# 242                 outdoor clothing equipment believe                    4
# 420                                clothes woman child                    3
# 435  believe website detailed global weather forcas...                   10
# 489                                   weather forecast                    2
# 516                                clothes woman child                    3
# 589                                    eyewar sunglass                    2
# 630                                           clothing                    1
# 696                                sustainable fashion                    2
#
#      purpose_word_count  ...  PQ3 HQ2  HQ3 ATT2  PQ4 HQ4    PQ    HQ  ATT  \
# 30                    1  ...    5   5    4    5    5   4  5.00  4.50  5.0
# 33                    2  ...    6   2    2    4    4   3  4.50  2.50  3.5
# 210                   2  ...    6   4    3    5    6   3  5.75  3.75  4.5
# 242                   6  ...    5   5    6    6    7   6  5.75  6.00  6.0
# 420                   6  ...    7   6    4    5    6   4  6.50  4.75  6.0
# 435                  17  ...    7   6    5    6    5   5  5.50  5.25  5.5
# 489                   2  ...    5   4    4    5    3   4  4.25  4.00  4.5
# 516                   6  ...    5   7    5    6    6   5  5.75  5.75  6.0
# 589                   3  ...    4   3    4    4    3   3  4.00  3.25  4.5
# 630                   1  ...    5   5    5    6    7   5  6.00  5.25  6.0
# 696                   2  ...    4   4    4    5    5   4  4.25  4.00  4.5
#
#      familiarity
# 30          True
# 33          True
# 210         True
# 242         True
# 420         True
# 435         True
# 489         True
# 516         True
# 589         True
# 630         True
# 696         True
#
# [11 rows x 34 columns]
